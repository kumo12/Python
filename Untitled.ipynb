# %% [markdown]
# mnumpy + pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = ['a','b','c','d']
y = [-10,10,20,15]

# %%
plt.plot(x)
plt.plot(y)

# %%
plt.plot(x,y)

# %%
x = ['A','B','C','D','E']
y = list(range(1,10,2))
plt.plot(x,y)

# %%
a = np.arange(0,2,0.5)
a
# Out:
# array([0. , 0.5, 1. , 1.5])

# %%
x = ['A','B','C','D','E']

# %%
a = list(range(1, 6, 1))
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b = [i*i for i in a ]
b
# Out:
# [1, 4, 9, 16, 25]

# %%
a = np.arange(0,2,0.5)
a
# Out:
# array([0. , 0.5, 1. , 1.5])

# %%
b = a*a
b
# Out:
# array([0.  , 0.25, 1.  , 2.25])

# %%
plt.plot(a,b)

# %%
c=10*a
c
# Out:
# array([ 0.,  5., 10., 15.])

# %%
plt.plot(a,b)
plt.plot(a,c)

# %%
plt.plot(a,b)
plt.figure()
plt.plot(a,c)

# %%
t=np.arange(0,12,1)
y1=np.sin(t)
y2=np.cos(t)
plt.plot(t,y1)
plt.plot(t,y2)
plt.grid()
plt.figure(figsize=(12,6))

# %%
plt.subplot(1,2,1)
plt.plot(t,y1, 'r--')
plt.subplot(1,2,2)
plt.plot(t,y2, 'go--')

# %% [markdown]
# ## [문제]
# subplot을 이용해서 1행2열 구조 2개씩
#  / 4가지 생상 다르게
#  / 4가지 스타일 다르게
#  / 4가지 마커 서로 다르게
#  / 범례표시
#  / x,y,제목
#
# x = 0부터 5까지 단위1
#
# y1 = x+1  /
# y2 = x+2  /
# y3 = x+3  /
# y4 = x+4  /
# y5 = x+5  /

# %%
p=np.arange(0,12,1)
y1 = x+1
y2 = x+2
y3 = x+3
y4 = x+4
y5 = x+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-8bc3f450d7ae> in <module>
#       1 p=np.arange(0,12,1)
# ----> 2 y1 = x+1
#       3 y2 = x+2
#       4 y3 = x+3
#       5 y4 = x+4
#
# TypeError: can only concatenate list (not "int") to list

# %%
plt.subplot(1,2,1)
plt.plot(t,y1, 'r--', marker='*')
plt.plot(p,y2, 'g--', marker='*')
plt.subplot(1,2,2)
plt.plot(p,y3, 'y--', marker='*')
plt.plot(p,y4, 'b--', marker='*')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-22dd71484e98> in <module>
#       1 plt.subplot(1,2,1)
#       2 plt.plot(t,y1, 'r--', marker='*')
# ----> 3 plt.plot(p,y2, 'g--', marker='*')
#       4 plt.subplot(1,2,2)
#       5 plt.plot(p,y3, 'y--', marker='*')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
plt.subplot(1,2,1)
plt.plot(t,y1, 'r--')
plt.plot(t,y2, 'g--')
plt.subplot(1,2,2)
plt.plot(t,y1, 'y--')
plt.plot(t,y2, 'b--')
