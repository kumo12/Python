# %% [markdown]
# <a href="https://colab.research.google.com/github/kumo12/Python/blob/master/%ED%8C%8C%EC%9D%B4%EC%8D%AC_3%EC%9D%BC%EC%B0%A8_1%EA%B5%90%EC%8B%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Type_Dictionary**

# %% [markdown]
# # Data_Type**

# %% [markdown]
# # [문제풀이]

# %% [markdown]
# #[문제1]'*'문자를 100번 출력하시오.
#
# ```
# # 코드로 형식 지정됨
# ```

# %%
print('*'*100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# # [문제2]input()내장 함수를 이용하여 id에 입력을 받기

# %%
id = input('id를 입력 >>> ')
print(id + '님! 안녕하세요.')
print(id, '님! 안녕하세요.')
# Out:
# id를 입력 >>> kumo
# kumo님! 안녕하세요.
# kumo 님! 안녕하세요.

# %%
type(id)
# Out:
# str

# %% [markdown]
# #[문제3]나의 나이를 입력받아 (변수 :gap)환갑이 되는 나이 년도 구해보기 '당신이 환갑이 되는 년도는 2032년 입니다.'와 같이 출력해보기

# %%
gap = input('태어난 년도를 입력 >>> ')
print('당신이 환갑이 되는 연도는 ', int(gap) + 60,'년 입니다.')
# Out:
# 태어난 년도를 입력 >>> 2002
# 당신이 환갑이 되는 연도는  2062 년 입니다.

# %% [markdown]
# #**[문제4]**
#
# 두개의 숫자를 입력받아 **, %,/,//
#
# ```
# #
# a, b = input('두개의 숫자 입력').split()
# ```

# %%
a, b = input('두개의 숫자 입력').split()
print(a,b)
# Out:
# 두개의 숫자 입력1 2
# 1 2

# %%
a= input('두개의 숫자 입력 >>> ' )

# %%
# dic = {1 : '예린이', 2 : '고유빈', 3 : 0409}

# %%
dic[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-44fd7baa145e> in <module>()
# ----> 1 dic[1]
#
# NameError: name 'dic' is not defined

# %%
dic.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-aa304cdb5893> in <module>()
# ----> 1 dic.values()
#
# NameError: name 'dic' is not defined

# %%
dic.items()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ea07470c4891> in <module>()
# ----> 1 dic.items()
#
# NameError: name 'dic' is not defined

# %%
dic.keys

# %%
a = '인천정보산업고등학교'
type(a)
# Out:
# str

# %%
type(dic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-81db759d599a> in <module>()
# ----> 1 type(dic)
#
# NameError: name 'dic' is not defined

# %%
b= [1,2,3,4,5]
type(b)
b[0]=8
b
# Out:
# [8, 2, 3, 4, 5]

# %%
c=1,2,3,4,5
type(c)
c[0] = 8
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e733d063219f> in <module>()
#       1 c=1,2,3,4,5
#       2 type(c)
# ----> 3 c[0] = 8
#       4 c
#
# TypeError: 'tuple' object does not support item assignment
